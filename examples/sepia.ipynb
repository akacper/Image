# %%
from Image import Image, plt

# %%
lena = Image("data/lena.jpg")

# %%
gray_lena = lena.to_gray()
print(gray_lena.color_model)
gray_lena.show_img()
# Out:
# ColorModel.gray

# %%
sepia_lena1 = lena.to_sepia(alpha_beta=(1.9, 0.1))
sepia_lena1.show_img()

# %%
sepia_lena2 = lena.to_sepia(w=20)
sepia_lena2.show_img()
