# %%
# %reset -f

# %%
from Image import Image, plt
import cv2

# %%
lena = Image("data/lena.png")
gray_lena = lena.to_gray()

# %%
gray_lena.otsu().show_img()

# %%
gray_lena.adaptive_threshold().show_img()

# %%
gray_lena.clahe().show_img()

# %%
lake = Image('data/swiecajty.jpg')
lake_gray = lake.to_gray()
lake_gray.clahe().show_img()

# %%
lake.clahe(tileGridSize=(8, 8)).show_img()

# %%
lena.clahe(tileGridSize=(8, 8)).show_img()
lake_color_equalized = lena.clahe(tileGridSize=(8, 8))
lake_color_equalized = lake_color_equalized.baseimage_to_image()
lake_color_equalized.histogram().plot()
